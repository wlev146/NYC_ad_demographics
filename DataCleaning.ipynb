# %% [markdown]
# ## Start Spark and Load Data

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
        .appName("Walrus_NYC_FootTraffic_311")
        .getOrCreate()
)

# local paths
turnstile_path = "/home/wlevine/Walrus/RawData/MTA_Subway_Hourly_Ridership__2020-2024_20251124 (1).csv"
sr311_path = "/home/wlevine/Walrus/RawData/311_Service_Requests_from_2010_to_Present_20251124.csv"

# loading week of turnstile data
turnstile_raw = (
    spark.read
         .option("header", "true")
         .option("inferSchema", "true")
         .csv(turnstile_path)
)

# loading same-week 311 data
sr311_raw = (
    spark.read
         .option("header", "true")
         .option("inferSchema", "true")
         .csv(sr311_path)
)

turnstile_raw.show(5)
sr311_raw.show(5)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/24 11:48:53 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/24 11:48:53 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/11/24 11:48:53 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/11/24 11:48:53 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 25/11/24 11:48:53 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 25/11/24 11:48:53 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.
# +--------------------+------------+------------------+--------------------+---------+--------------+--------------------+---------+---------+---------+---------+--------------------+
# |   transit_timestamp|transit_mode|station_complex_id|     station_complex|  borough|payment_method| fare_class_category|ridership|transfers| latitude|longitude|        Georeference|
# +--------------------+------------+------------------+--------------------+---------+--------------+--------------------+---------+---------+---------+---------+--------------------+
# |02/05/2024 12:00:...|      subway|               349|       Junius St (3)| Brooklyn|     metrocard|Metrocard - Full ...|        4|        1|40.663513|-73.90245|POINT (-73.90245 ...|
# |02/05/2024 12:00:...|      subway|               272|         36 St (M,R)|   Queens|     metrocard|Metrocard - Unlim...|        1|        0| 40.75204|-73.92878|POINT (-73.92878 ...|
# |02/05/2024 12:00:...|      subway|                84|85 St-Forest Pkwy...|   Queens|     metrocard|   Metrocard - Other|        1|        0|40.692436|-73.86001|POINT (-73.86001 ...|
# |02/05/2024 12:00:...|      subway|               160|         72 St (C,B)|Manhattan|     metrocard|Metrocard - Unlim...|        4|        0|40.775593|-73.97641|POINT (-73.97641 ...|
# |02/05/2024 12:00:...|      subway|                33|           45 St (R)| Brooklyn|     metrocard|Metrocard - Unlim...|        1|        0|40.648937|-74.01001|POINT (-74.01001 ...|
# +--------------------+------------+------------------+--------------------+---------+--------------+--------------------+---------+---------+---------+---------+--------------------+
# only showing top 5 rows
# 25/11/24 11:48:59 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +----------+--------------------+--------------------+------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+-----------------+-----------------+---------------------+---------------------+------------+----------------+--------------------+-------------+------+--------+----------------------+------------------------------+---------------+----------+---------+--------------------------+--------------------------+----------------------+------------------+------------+------------+--------------------+---------------------+-------------------+------------------------+---------+----------------------+--------------+---------------+--------------------+
# |Unique Key|        Created Date|         Closed Date|Agency|         Agency Name|      Complaint Type|          Descriptor|       Location Type|Incident Zip|    Incident Address|         Street Name|   Cross Street 1|   Cross Street 2|Intersection Street 1|Intersection Street 2|Address Type|            City|            Landmark|Facility Type|Status|Due Date|Resolution Description|Resolution Action Updated Date|Community Board|       BBL|  Borough|X Coordinate (State Plane)|Y Coordinate (State Plane)|Open Data Channel Type|Park Facility Name|Park Borough|Vehicle Type|Taxi Company Borough|Taxi Pick Up Location|Bridge Highway Name|Bridge Highway Direction|Road Ramp|Bridge Highway Segment|      Latitude|      Longitude|            Location|
# +----------+--------------------+--------------------+------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+-----------------+-----------------+---------------------+---------------------+------------+----------------+--------------------+-------------+------+--------+----------------------+------------------------------+---------------+----------+---------+--------------------------+--------------------------+----------------------+------------------+------------+------------+--------------------+---------------------+-------------------+------------------------+---------+----------------------+--------------+---------------+--------------------+
# |  60313278|02/12/2024 11:59:...|02/13/2024 02:32:...|  NYPD|New York City Pol...|     Illegal Parking|    Blocked Sidewalk|     Street/Sidewalk|       11385|     79-40 78 AVENUE|           78 AVENUE|         79 PLACE|        80 STREET|             79 PLACE|            80 STREET|     ADDRESS|       RIDGEWOOD|           78 AVENUE|         NULL|Closed|    NULL|  The Police Depart...|          02/13/2024 02:32:...|      05 QUEENS|4038290065|   QUEENS|                 1,020,264|                   196,160|                MOBILE|       Unspecified|      QUEENS|        NULL|                NULL|                 NULL|               NULL|                    NULL|     NULL|                  NULL|40.70501735978|-73.87010741405|(40.7050173597847...|
# |  60316062|02/12/2024 11:59:...|02/13/2024 12:17:...|  NYPD|New York City Pol...|  Noise - Commercial|    Banging/Pounding|    Store/Commercial|       10025| 920 COLUMBUS AVENUE|     COLUMBUS AVENUE| WEST  105 STREET| WEST  106 STREET|     WEST  105 STREET|     WEST  106 STREET|     ADDRESS|        NEW YORK|     COLUMBUS AVENUE|         NULL|Closed|    NULL|  The Police Depart...|          02/13/2024 12:17:...|   07 MANHATTAN|1018600029|MANHATTAN|                   994,414|                   230,255|                 PHONE|       Unspecified|   MANHATTAN|        NULL|                NULL|                 NULL|               NULL|                    NULL|     NULL|                  NULL|40.79866693989|-73.96328968976|(40.7986669398904...|
# |  60314286|02/12/2024 11:58:...|09/06/2024 06:47:...|   TLC|Taxi and Limousin...|For Hire Vehicle ...|Driver Complaint ...|              Street|       11101|44-07 VERNON BOUL...|    VERNON BOULEVARD|        44 AVENUE|          44 ROAD|            44 AVENUE|              44 ROAD|     ADDRESS|LONG ISLAND CITY|    VERNON BOULEVARD|         NULL|Closed|    NULL|  A hearing was sch...|          09/06/2024 06:47:...|      02 QUEENS|4004520005|   QUEENS|                   997,482|                   212,631|                ONLINE|       Unspecified|      QUEENS|        NULL|                NULL| 44-07 VERNON BOUL...|               NULL|                    NULL|     NULL|                  NULL|40.75028962808|-73.95224340014|(40.7502896280768...|
# |  60311957|02/12/2024 11:58:...|02/13/2024 04:58:...|  NYPD|New York City Pol...|     Illegal Parking|     Blocked Hydrant|     Street/Sidewalk|       11223|1906 WEST   13 ST...|    WEST   13 STREET|         AVENUE S|         AVENUE T|             AVENUE S|             AVENUE T|     ADDRESS|        BROOKLYN|    WEST   13 STREET|         NULL|Closed|    NULL|  The Police Depart...|          02/13/2024 04:58:...|    11 BROOKLYN|3070750008| BROOKLYN|                   988,451|                   157,861|                ONLINE|       Unspecified|    BROOKLYN|        NULL|                NULL|                 NULL|               NULL|                    NULL|     NULL|                  NULL|40.59996725822|-73.98487199397|(40.5999672582221...|
# |  60309807|02/12/2024 11:58:...|02/13/2024 02:30:...|  NYPD|New York City Pol...| Noise - Residential|    Loud Music/Party|Residential Build...|       11691|45-19 ROCKAWAY BE...|ROCKAWAY BEACH BO...|BEACH   45 STREET|BEACH   46 STREET|    BEACH   45 STREET|    BEACH   46 STREET|     ADDRESS|    FAR ROCKAWAY|ROCKAWAY BEACH BO...|         NULL|Closed|    NULL|  The Police Depart...|          02/13/2024 02:30:...|      14 QUEENS|4158537502|   QUEENS|                 1,046,308|                   155,618|                 PHONE|       Unspecified|      QUEENS|        NULL|                NULL|                 NULL|               NULL|                    NULL|     NULL|                  NULL|40.59359441443|-73.77654719988|(40.5935944144253...|
# +----------+--------------------+--------------------+------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+--------------------+-----------------+-----------------+---------------------+---------------------+------------+----------------+--------------------+-------------+------+--------+----------------------+------------------------------+---------------+----------+---------+--------------------------+--------------------------+----------------------+------------------+------------+------------+--------------------+---------------------+-------------------+------------------------+---------+----------------------+--------------+---------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ## Turnstile Data

# %%
from pyspark.sql.functions import (
    col,
    to_timestamp,
    to_date,
    hour,
    dayofweek,
    when
)

# start from the raw turnstile pull and keep the columns we actually care about
turnstile_sel = (
    turnstile_raw
        .select(
            "transit_timestamp",
            "transit_mode",
            "station_complex_id",
            "station_complex",
            "borough",
            "payment_method",
            "fare_class_category",
            "ridership",
            "transfers",
            "latitude",
            "longitude",
            "Georeference"
        )
)

# parse the timestamp string into a proper timestamp column
# format here matches: 02/05/2024 12:00:00 AM
turnstile_sel = turnstile_sel.withColumn(
    "dt",
    to_timestamp(col("transit_timestamp"), "MM/dd/yyyy hh:mm:ss a")
)

# drop any weird rows where timestamp didn't parse
turnstile_sel = turnstile_sel.filter(col("dt").isNotNull())

# basic time breakdowns that we'll use later
turnstile_sel = (
    turnstile_sel
        .withColumn("date", to_date(col("dt")))
        .withColumn("hour", hour(col("dt")))
        .withColumn("weekday_num", dayofweek(col("dt")))  # 1 = Sun, 7 = Sat
        .withColumn(
            "is_weekend",
            when(col("weekday_num").isin(1, 7), 1).otherwise(0)
        )
)

# make sure ridership + transfers are numeric and get a total flow metric
turnstile_sel = (
    turnstile_sel
        .withColumn("ridership", col("ridership").cast("int"))
        .withColumn("transfers", col("transfers").cast("int"))
        .withColumn("total_flow", col("ridership") + col("transfers"))
)

# bucket the day into something that plays nicely in visuals
turnstile_sel = (
    turnstile_sel
        .withColumn(
            "tod_bucket",
            when((col("hour") >= 7) & (col("hour") < 10), "AM Peak")
            .when((col("hour") >= 16) & (col("hour") < 19), "PM Peak")
            .otherwise("Off-Peak")
        )
)

# final ordered version of the table we'll use going forward
turnstile_final = (
    turnstile_sel
        .select(
            "dt",
            "date",
            "hour",
            "weekday_num",
            "is_weekend",
            "tod_bucket",
            "transit_mode",
            "station_complex_id",
            "station_complex",
            "borough",
            "payment_method",
            "fare_class_category",
            "ridership",
            "transfers",
            "total_flow",
            "latitude",
            "longitude",
            "Georeference"
        )
)

# quick sanity check
turnstile_final.show(20, truncate=False)
turnstile_final.printSchema()
# Out:
# +-------------------+----------+----+-----------+----------+----------+------------+------------------+---------------------------------+---------+--------------+--------------------------------+---------+---------+----------+---------+----------+----------------------------+
# |dt                 |date      |hour|weekday_num|is_weekend|tod_bucket|transit_mode|station_complex_id|station_complex                  |borough  |payment_method|fare_class_category             |ridership|transfers|total_flow|latitude |longitude |Georeference                |
# +-------------------+----------+----+-----------+----------+----------+------------+------------------+---------------------------------+---------+--------------+--------------------------------+---------+---------+----------+---------+----------+----------------------------+
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |349               |Junius St (3)                    |Brooklyn |metrocard     |Metrocard - Full Fare           |4        |1        |5         |40.663513|-73.90245 |POINT (-73.90245 40.663513) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |272               |36 St (M,R)                      |Queens   |metrocard     |Metrocard - Unlimited 7-Day     |1        |0        |1         |40.75204 |-73.92878 |POINT (-73.92878 40.75204)  |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |84                |85 St-Forest Pkwy (J)            |Queens   |metrocard     |Metrocard - Other               |1        |0        |1         |40.692436|-73.86001 |POINT (-73.86001 40.692436) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |160               |72 St (C,B)                      |Manhattan|metrocard     |Metrocard - Unlimited 7-Day     |4        |0        |4         |40.775593|-73.97641 |POINT (-73.97641 40.775593) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |33                |45 St (R)                        |Brooklyn |metrocard     |Metrocard - Unlimited 30-Day    |1        |0        |1         |40.648937|-74.01001 |POINT (-74.01001 40.648937) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |138               |Canarsie-Rockaway Pkwy (L)       |Brooklyn |metrocard     |Metrocard - Fair Fare           |1        |0        |1         |40.646652|-73.90185 |POINT (-73.90185 40.646652) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |17                |Prince St (R,W)                  |Manhattan|metrocard     |Metrocard - Unlimited 7-Day     |10       |0        |10        |40.72433 |-73.9977  |POINT (-73.9977 40.72433)   |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |630               |Myrtle-Wyckoff Avs (L,M)         |Brooklyn |metrocard     |Metrocard - Other               |2        |0        |2         |40.699814|-73.91158 |POINT (-73.91158 40.699814) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |68                |Bay Pkwy (D)                     |Brooklyn |omny          |OMNY - Full Fare                |3        |0        |3         |40.601875|-73.99373 |POINT (-73.99373 40.601875) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |10                |49 St (N,R,W)                    |Manhattan|metrocard     |Metrocard - Full Fare           |20       |0        |20        |40.7599  |-73.98414 |POINT (-73.98414 40.7599)   |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |107               |Broad St (J,Z)                   |Manhattan|metrocard     |Metrocard - Unlimited 30-Day    |3        |0        |3         |40.706474|-74.011055|POINT (-74.011055 40.706474)|
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |396               |96 St (6)                        |Manhattan|metrocard     |Metrocard - Unlimited 30-Day    |3        |0        |3         |40.78567 |-73.95107 |POINT (-73.95107 40.78567)  |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |266               |Elmhurst Av (M,R)                |Queens   |omny          |OMNY - Full Fare                |3        |0        |3         |40.742455|-73.88202 |POINT (-73.88202 40.742455) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |614               |59 St-Columbus Circle (A,B,C,D,1)|Manhattan|metrocard     |Metrocard - Students            |1        |0        |1         |40.768295|-73.981735|POINT (-73.981735 40.768295)|
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |10                |49 St (N,R,W)                    |Manhattan|metrocard     |Metrocard - Fair Fare           |6        |0        |6         |40.7599  |-73.98414 |POINT (-73.98414 40.7599)   |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |324               |Houston St (1)                   |Manhattan|metrocard     |Metrocard - Seniors & Disability|1        |0        |1         |40.728252|-74.00536 |POINT (-74.00536 40.728252) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |53                |Neck Rd (Q)                      |Brooklyn |metrocard     |Metrocard - Unlimited 30-Day    |1        |0        |1         |40.595245|-73.95516 |POINT (-73.95516 40.595245) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |67                |20 Av (D)                        |Brooklyn |omny          |OMNY - Full Fare                |6        |0        |6         |40.604557|-73.99817 |POINT (-73.99817 40.604557) |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |41                |7 Av (B,Q)                       |Brooklyn |metrocard     |Metrocard - Unlimited 30-Day    |1        |0        |1         |40.67705 |-73.97237 |POINT (-73.97237 40.67705)  |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |35                |59 St (N,R)                      |Brooklyn |metrocard     |Metrocard - Other               |3        |0        |3         |40.64136 |-74.01788 |POINT (-74.01788 40.64136)  |
# +-------------------+----------+----+-----------+----------+----------+------------+------------------+---------------------------------+---------+--------------+--------------------------------+---------+---------+----------+---------+----------+----------------------------+
# only showing top 20 rows
#
# root
#  |-- dt: timestamp (nullable = true)
#  |-- date: date (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- weekday_num: integer (nullable = true)
#  |-- is_weekend: integer (nullable = false)
#  |-- tod_bucket: string (nullable = false)
#  |-- transit_mode: string (nullable = true)
#  |-- station_complex_id: string (nullable = true)
#  |-- station_complex: string (nullable = true)
#  |-- borough: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- fare_class_category: string (nullable = true)
#  |-- ridership: integer (nullable = true)
#  |-- transfers: integer (nullable = true)
#  |-- total_flow: integer (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- Georeference: string (nullable = true)

# %%
from pyspark.sql import functions as F

ts = turnstile_final

# %%
# fill any nulls on ridership/transfers and total_flow
ts = (
    ts.withColumn("ridership", F.coalesce("ridership", F.lit(0)))
      .withColumn("transfers", F.coalesce("transfers", F.lit(0)))
      .withColumn("total_flow", F.coalesce("total_flow", F.col("ridership") + F.col("transfers")))
)

# no need to keep rows with 0 total flow
ts = ts.filter(F.col("total_flow") > 0)

# %%
# quick label for weekday on charts
ts = ts.withColumn("day_name", F.date_format("date", "E"))

# %%
# cleaner label than 0/1 when slicing
ts = ts.withColumn(
    "week_part",
    F.when(F.col("is_weekend") == 1, F.lit("Weekend")).otherwise(F.lit("Weekday"))
)

# %%
# hour bucket across the whole week (mon 0:00 = 0, ... )
ts = ts.withColumn(
    "hour_of_week",
    F.col("weekday_num") * F.lit(24) + F.col("hour")
)

# %%
# clean up payment method a bit
ts = ts.withColumn("payment_method_clean", F.trim(F.lower("payment_method")))

# high level bucket here so plots don't get crazy
ts = ts.withColumn(
    "payment_group",
    F.when(F.col("payment_method_clean") == "metrocard", "MetroCard")
     .when(F.col("payment_method_clean") == "omny", "OMNY")
     .otherwise("Other")
)

# %%
# collapse all those long fare strings into something usable
ts = ts.withColumn(
    "fare_bucket",
    F.when(F.col("fare_class_category").like("%Full Fare%"), "Full Fare")
     .when(F.col("fare_class_category").like("%Unlimited%"), "Unlimited")
     .when(F.col("fare_class_category").like("%Discount%"), "Discount/Reduced")
     .when(F.col("fare_class_category").like("%Fair Fare%"), "Fair Fares")
     .otherwise("Other")
)

# %%
# clean up any weird spacing in station names
ts = ts.withColumn("station_clean", F.regexp_replace("station_complex", r"\s+", " "))

# rounded lat/lon to group or join easier with 311 later
ts = (
    ts.withColumn("lat_4", F.round("latitude", 4))
      .withColumn("lon_4", F.round("longitude", 4))
)

# %%
# this is the version i'll use going forward
turnstile_model_df = ts

turnstile_model_df.printSchema()
turnstile_model_df.show(5, truncate=False)
# Out:
# root
#  |-- dt: timestamp (nullable = true)
#  |-- date: date (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- weekday_num: integer (nullable = true)
#  |-- is_weekend: integer (nullable = false)
#  |-- tod_bucket: string (nullable = false)
#  |-- transit_mode: string (nullable = true)
#  |-- station_complex_id: string (nullable = true)
#  |-- station_complex: string (nullable = true)
#  |-- borough: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- fare_class_category: string (nullable = true)
#  |-- ridership: integer (nullable = false)
#  |-- transfers: integer (nullable = false)
#  |-- total_flow: integer (nullable = false)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- Georeference: string (nullable = true)
#  |-- day_name: string (nullable = true)
#  |-- week_part: string (nullable = false)
#  |-- hour_of_week: integer (nullable = true)
#  |-- payment_method_clean: string (nullable = true)
#  |-- payment_group: string (nullable = false)
#  |-- fare_bucket: string (nullable = false)
#  |-- station_clean: string (nullable = true)
#  |-- lat_4: double (nullable = true)
#  |-- lon_4: double (nullable = true)
#
# +-------------------+----------+----+-----------+----------+----------+------------+------------------+---------------------+---------+--------------+----------------------------+---------+---------+----------+---------+---------+---------------------------+--------+---------+------------+--------------------+-------------+-----------+---------------------+-------+--------+
# |dt                 |date      |hour|weekday_num|is_weekend|tod_bucket|transit_mode|station_complex_id|station_complex      |borough  |payment_method|fare_class_category         |ridership|transfers|total_flow|latitude |longitude|Georeference               |day_name|week_part|hour_of_week|payment_method_clean|payment_group|fare_bucket|station_clean        |lat_4  |lon_4   |
# +-------------------+----------+----+-----------+----------+----------+------------+------------------+---------------------+---------+--------------+----------------------------+---------+---------+----------+---------+---------+---------------------------+--------+---------+------------+--------------------+-------------+-----------+---------------------+-------+--------+
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |349               |Junius St (3)        |Brooklyn |metrocard     |Metrocard - Full Fare       |4        |1        |5         |40.663513|-73.90245|POINT (-73.90245 40.663513)|Mon     |Weekday  |48          |metrocard           |MetroCard    |Full Fare  |Junius St (3)        |40.6635|-73.9025|
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |272               |36 St (M,R)          |Queens   |metrocard     |Metrocard - Unlimited 7-Day |1        |0        |1         |40.75204 |-73.92878|POINT (-73.92878 40.75204) |Mon     |Weekday  |48          |metrocard           |MetroCard    |Unlimited  |36 St (M,R)          |40.752 |-73.9288|
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |84                |85 St-Forest Pkwy (J)|Queens   |metrocard     |Metrocard - Other           |1        |0        |1         |40.692436|-73.86001|POINT (-73.86001 40.692436)|Mon     |Weekday  |48          |metrocard           |MetroCard    |Other      |85 St-Forest Pkwy (J)|40.6924|-73.86  |
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |160               |72 St (C,B)          |Manhattan|metrocard     |Metrocard - Unlimited 7-Day |4        |0        |4         |40.775593|-73.97641|POINT (-73.97641 40.775593)|Mon     |Weekday  |48          |metrocard           |MetroCard    |Unlimited  |72 St (C,B)          |40.7756|-73.9764|
# |2024-02-05 00:00:00|2024-02-05|0   |2          |0         |Off-Peak  |subway      |33                |45 St (R)            |Brooklyn |metrocard     |Metrocard - Unlimited 30-Day|1        |0        |1         |40.648937|-74.01001|POINT (-74.01001 40.648937)|Mon     |Weekday  |48          |metrocard           |MetroCard    |Unlimited  |45 St (R)            |40.6489|-74.01  |
# +-------------------+----------+----+-----------+----------+----------+------------+------------------+---------------------+---------+--------------+----------------------------+---------+---------+----------+---------+---------+---------------------------+--------+---------+------------+--------------------+-------------+-----------+---------------------+-------+--------+
# only showing top 5 rows

# %% [markdown]
# ## 311 Data

# %%
from pyspark.sql.functions import (
    to_timestamp, to_date, hour, dayofweek, date_format,
    trim, lower, regexp_replace, col, when,
    substring_index, concat_ws, round
)
from pyspark.sql.types import DoubleType

# start with the raw frame
df311 = sr311_raw

# keep only the columns we actually use in this project
df311 = (
    df311.select(
        "Created Date",
        "Closed Date",
        "Agency",
        "Agency Name",
        "Complaint Type",
        "Descriptor",
        "Location Type",
        "Incident Zip",
        "Incident Address",
        "Street Name",
        "Cross Street 1",
        "Cross Street 2",
        "Intersection Street 1",
        "Intersection Street 2",
        "City",
        "Borough",
        "Latitude",
        "Longitude"
    )
)

# rename to cleaner column names
df311 = (
    df311.withColumnRenamed("Created Date", "created_dt")
         .withColumnRenamed("Closed Date", "closed_dt")
         .withColumnRenamed("Complaint Type", "complaint")
         .withColumnRenamed("Descriptor", "descriptor")
         .withColumnRenamed("Location Type", "location_type")
         .withColumnRenamed("Incident Zip", "zip")
         .withColumnRenamed("Incident Address", "address")
         .withColumnRenamed("Street Name", "street")
         .withColumnRenamed("Cross Street 1", "cross1")
         .withColumnRenamed("Cross Street 2", "cross2")
         .withColumnRenamed("Intersection Street 1", "inter1")
         .withColumnRenamed("Intersection Street 2", "inter2")
)

# convert timestamp
df311 = (
    df311.withColumn("dt", to_timestamp("created_dt", "MM/dd/yyyy hh:mm:ss a"))
         .withColumn("date", to_date("dt"))
         .withColumn("hour", hour("dt"))
         .withColumn("weekday_num", dayofweek("dt"))
         .withColumn("day_name", date_format("dt", "EEEE"))
)

# weekend flag
df311 = df311.withColumn(
    "is_weekend",
    when(col("weekday_num").isin(1,7), 1).otherwise(0)
)

# coarse time-of-day bucket
df311 = df311.withColumn(
    "tod_bucket",
    when((col("hour") >= 7) & (col("hour") < 10), "AM Peak")
    .when((col("hour") >= 16) & (col("hour") < 19), "PM Peak")
    .otherwise("Off-Peak")
)

# normalize complaint type categories
df311 = (
    df311.withColumn("complaint_clean", lower(trim(col("complaint"))))
         .withColumn("complaint_clean", regexp_replace("complaint_clean", r"\s+", "_"))
)

# group complaints into higher-level buckets
df311 = df311.withColumn(
    "complaint_group",
    when(col("complaint_clean").rlike("noise|music|party"), "noise")
    .when(col("complaint_clean").rlike("sanitation|dirty|sweeping"), "sanitation")
    .when(col("complaint_clean").rlike("rodent|rat|mouse"), "rodent")
    .when(col("complaint_clean").rlike("heat|hot_water"), "heat_hot_water")
    .otherwise("other")
)

# clean borough
df311 = (
    df311.withColumn("borough_clean", trim(col("Borough")))
         .withColumn("borough_clean", lower(col("borough_clean")))
)

# latitude / longitude fix
df311 = (
    df311.withColumn("lat", col("Latitude").cast(DoubleType()))
         .withColumn("lon", col("Longitude").cast(DoubleType()))
         .withColumn("lat_4", round(col("lat"), 4))
         .withColumn("lon_4", round(col("lon"), 4))
)

# final ordered columns
sr311_final = df311.select(
    "dt","date","hour","weekday_num","day_name","is_weekend","tod_bucket",
    "complaint","descriptor","complaint_clean","complaint_group",
    "agency","Agency Name",
    "location_type","zip","address","street","cross1","cross2","inter1","inter2",
    "city","borough_clean",
    "lat","lon","lat_4","lon_4"
)

sr311_final.show(20, truncate=False)
# Out:
# +-------------------+----------+----+-----------+--------+----------+----------+--------------------------+--------------------------------------------+--------------------------+---------------+------+--------------------------------------------------+--------------------------+-----+------------------------------+------------------------+-----------------+-----------------------+-----------------+-----------------------+----------------+-------------+--------------+---------------+-------+--------+
# |dt                 |date      |hour|weekday_num|day_name|is_weekend|tod_bucket|complaint                 |descriptor                                  |complaint_clean           |complaint_group|agency|Agency Name                                       |location_type             |zip  |address                       |street                  |cross1           |cross2                 |inter1           |inter2                 |city            |borough_clean|lat           |lon            |lat_4  |lon_4   |
# +-------------------+----------+----+-----------+--------+----------+----------+--------------------------+--------------------------------------------+--------------------------+---------------+------+--------------------------------------------------+--------------------------+-----+------------------------------+------------------------+-----------------+-----------------------+-----------------+-----------------------+----------------+-------------+--------------+---------------+-------+--------+
# |2024-02-12 23:59:56|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Illegal Parking           |Blocked Sidewalk                            |illegal_parking           |other          |NYPD  |New York City Police Department                   |Street/Sidewalk           |11385|79-40 78 AVENUE               |78 AVENUE               |79 PLACE         |80 STREET              |79 PLACE         |80 STREET              |RIDGEWOOD       |queens       |40.70501735978|-73.87010741405|40.705 |-73.8701|
# |2024-02-12 23:59:25|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Noise - Commercial        |Banging/Pounding                            |noise_-_commercial        |noise          |NYPD  |New York City Police Department                   |Store/Commercial          |10025|920 COLUMBUS AVENUE           |COLUMBUS AVENUE         |WEST  105 STREET |WEST  106 STREET       |WEST  105 STREET |WEST  106 STREET       |NEW YORK        |manhattan    |40.79866693989|-73.96328968976|40.7987|-73.9633|
# |2024-02-12 23:58:55|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |For Hire Vehicle Complaint|Driver Complaint - Non Passenger            |for_hire_vehicle_complaint|other          |TLC   |Taxi and Limousine Commission                     |Street                    |11101|44-07 VERNON BOULEVARD        |VERNON BOULEVARD        |44 AVENUE        |44 ROAD                |44 AVENUE        |44 ROAD                |LONG ISLAND CITY|queens       |40.75028962808|-73.95224340014|40.7503|-73.9522|
# |2024-02-12 23:58:44|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Illegal Parking           |Blocked Hydrant                             |illegal_parking           |other          |NYPD  |New York City Police Department                   |Street/Sidewalk           |11223|1906 WEST   13 STREET         |WEST   13 STREET        |AVENUE S         |AVENUE T               |AVENUE S         |AVENUE T               |BROOKLYN        |brooklyn     |40.59996725822|-73.98487199397|40.6   |-73.9849|
# |2024-02-12 23:58:23|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Noise - Residential       |Loud Music/Party                            |noise_-_residential       |noise          |NYPD  |New York City Police Department                   |Residential Building/House|11691|45-19 ROCKAWAY BEACH BOULEVARD|ROCKAWAY BEACH BOULEVARD|BEACH   45 STREET|BEACH   46 STREET      |BEACH   45 STREET|BEACH   46 STREET      |FAR ROCKAWAY    |queens       |40.59359441443|-73.77654719988|40.5936|-73.7765|
# |2024-02-12 23:58:17|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Illegal Parking           |Blocked Bike Lane                           |illegal_parking           |other          |NYPD  |New York City Police Department                   |Street/Sidewalk           |11101|44-07 VERNON BOULEVARD        |VERNON BOULEVARD        |44 AVENUE        |44 ROAD                |44 AVENUE        |44 ROAD                |LONG ISLAND CITY|queens       |40.75028962808|-73.95224340014|40.7503|-73.9522|
# |2024-02-12 23:58:09|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |HEAT/HOT WATER            |ENTIRE BUILDING                             |heat/hot_water            |heat_hot_water |HPD   |Department of Housing Preservation and Development|RESIDENTIAL BUILDING      |10463|225 WEST  232 STREET          |WEST  232 STREET        |NULL             |NULL                   |NULL             |NULL                   |BRONX           |bronx        |40.88035133975|-73.90431802232|40.8804|-73.9043|
# |2024-02-12 23:57:50|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Noise - Vehicle           |Engine Idling                               |noise_-_vehicle           |noise          |NYPD  |New York City Police Department                   |Street/Sidewalk           |10301|133 BENZIGER AVENUE           |BENZIGER AVENUE         |WESTERVELT AVENUE|BISMARK AVENUE         |WESTERVELT AVENUE|BISMARK AVENUE         |STATEN ISLAND   |staten island|40.63977611469|-74.0831293727 |40.6398|-74.0831|
# |2024-02-12 23:57:42|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Noise - Residential       |Loud Television                             |noise_-_residential       |noise          |NYPD  |New York City Police Department                   |Residential Building/House|10460|1778 SOUTHERN BOULEVARD       |SOUTHERN BOULEVARD      |CROTONA PARK EAST|EAST  175 STREET       |CROTONA PARK EAST|EAST  175 STREET       |BRONX           |bronx        |40.83830349819|-73.88718331369|40.8383|-73.8872|
# |2024-02-12 23:57:37|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Blocked Driveway          |Partial Access                              |blocked_driveway          |other          |NYPD  |New York City Police Department                   |Street/Sidewalk           |10301|140 BENZIGER AVENUE           |BENZIGER AVENUE         |WESTERVELT AVENUE|BISMARK AVENUE         |WESTERVELT AVENUE|BISMARK AVENUE         |STATEN ISLAND   |staten island|40.63973206775|-74.08330947764|40.6397|-74.0833|
# |2024-02-12 23:57:18|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |HEAT/HOT WATER            |ENTIRE BUILDING                             |heat/hot_water            |heat_hot_water |HPD   |Department of Housing Preservation and Development|RESIDENTIAL BUILDING      |11226|93 LINDEN BOULEVARD           |LINDEN BOULEVARD        |NULL             |NULL                   |NULL             |NULL                   |BROOKLYN        |brooklyn     |40.65237123967|-73.95506325152|40.6524|-73.9551|
# |2024-02-12 23:57:14|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |HEAT/HOT WATER            |ENTIRE BUILDING                             |heat/hot_water            |heat_hot_water |HPD   |Department of Housing Preservation and Development|RESIDENTIAL BUILDING      |11204|1729 67 STREET                |67 STREET               |NULL             |NULL                   |NULL             |NULL                   |BROOKLYN        |brooklyn     |40.61869577853|-73.99304442375|40.6187|-73.993 |
# |2024-02-12 23:57:10|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Illegal Parking           |Commercial Overnight Parking                |illegal_parking           |other          |NYPD  |New York City Police Department                   |Street/Sidewalk           |11224|2864 WEST   25 STREET         |WEST   25 STREET        |NEPTUNE AVENUE   |MERMAID AVENUE         |NEPTUNE AVENUE   |MERMAID AVENUE         |BROOKLYN        |brooklyn     |40.57678816227|-73.9923900247 |40.5768|-73.9924|
# |2024-02-12 23:57:02|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |HEAT/HOT WATER            |ENTIRE BUILDING                             |heat/hot_water            |heat_hot_water |HPD   |Department of Housing Preservation and Development|RESIDENTIAL BUILDING      |11429|111-41 208 STREET             |208 STREET              |NULL             |NULL                   |NULL             |NULL                   |QUEENS VILLAGE  |queens       |40.70552645196|-73.74834581667|40.7055|-73.7483|
# |2024-02-12 23:57:00|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |HEAT/HOT WATER            |ENTIRE BUILDING                             |heat/hot_water            |heat_hot_water |HPD   |Department of Housing Preservation and Development|RESIDENTIAL BUILDING      |10466|646 EAST  236 STREET          |EAST  236 STREET        |NULL             |NULL                   |NULL             |NULL                   |BRONX           |bronx        |40.89612665715|-73.85790243431|40.8961|-73.8579|
# |2024-02-12 23:56:47|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Noise - Vehicle           |Car/Truck Horn                              |noise_-_vehicle           |noise          |NYPD  |New York City Police Department                   |Street/Sidewalk           |10018|407 WEST   36 STREET          |WEST   36 STREET        |9 AVENUE         |LINCOLN TUNNEL ENTRANCE|9 AVENUE         |LINCOLN TUNNEL ENTRANCE|NEW YORK        |manhattan    |40.75481455423|-73.99564703983|40.7548|-73.9956|
# |2024-02-12 23:56:26|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Traffic                   |Chronic Speeding                            |traffic                   |other          |NYPD  |New York City Police Department                   |Street/Sidewalk           |11420|126-18 150 AVENUE             |150 AVENUE              |126 STREET       |127 STREET             |126 STREET       |127 STREET             |SOUTH OZONE PARK|queens       |40.66552605037|-73.81442485311|40.6655|-73.8144|
# |2024-02-12 23:56:00|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Noise                     |Noise: Construction Before/After Hours (NM1)|noise                     |noise          |DEP   |Department of Environmental Protection            |NULL                      |10025|920 COLUMBUS AVENUE           |COLUMBUS AVENUE         |W 105 ST         |W 106 ST               |NULL             |NULL                   |NEW YORK        |manhattan    |40.79866693989|-73.96328968976|40.7987|-73.9633|
# |2024-02-12 23:56:00|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Noise                     |Noise: Alarms (NR3)                         |noise                     |noise          |DEP   |Department of Environmental Protection            |NULL                      |10023|NULL                          |NULL                    |NULL             |NULL                   |WEST 73 STREET   |WEST END AVENUE        |MANHATTAN       |manhattan    |40.78049057087|-73.98397882924|40.7805|-73.984 |
# |2024-02-12 23:55:58|2024-02-12|23  |2          |Monday  |0         |Off-Peak  |Noise - Residential       |Loud Music/Party                            |noise_-_residential       |noise          |NYPD  |New York City Police Department                   |Residential Building/House|11203|886 LINDEN BOULEVARD          |LINDEN BOULEVARD        |EAST   55 STREET |EAST   56 STREET       |EAST   55 STREET |EAST   56 STREET       |BROOKLYN        |brooklyn     |40.65413699544|-73.92510222976|40.6541|-73.9251|
# +-------------------+----------+----+-----------+--------+----------+----------+--------------------------+--------------------------------------------+--------------------------+---------------+------+--------------------------------------------------+--------------------------+-----+------------------------------+------------------------+-----------------+-----------------------+-----------------+-----------------------+----------------+-------------+--------------+---------------+-------+--------+
# only showing top 20 rows

# %% [markdown]
# ## Joining Data

# %%
from pyspark.sql import functions as F

turnstile_final = (
    turnstile_final
        .withColumn("lat_4", F.round(F.col("latitude"), 4))
        .withColumn("lon_4", F.round(F.col("longitude"), 4))
)

# %%
turnstile_final.printSchema()
# Out:
# root
#  |-- dt: timestamp (nullable = true)
#  |-- date: date (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- weekday_num: integer (nullable = true)
#  |-- is_weekend: integer (nullable = false)
#  |-- tod_bucket: string (nullable = false)
#  |-- transit_mode: string (nullable = true)
#  |-- station_complex_id: string (nullable = true)
#  |-- station_complex: string (nullable = true)
#  |-- borough: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- fare_class_category: string (nullable = true)
#  |-- ridership: integer (nullable = true)
#  |-- transfers: integer (nullable = true)
#  |-- total_flow: integer (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- Georeference: string (nullable = true)
#  |-- lat_4: double (nullable = true)
#  |-- lon_4: double (nullable = true)

# %%
turn_with_grid = turnstile_final.withColumn(
    "grid_key",
    F.concat_ws("_", F.col("lat_4"), F.col("lon_4"))
)

sr311_with_grid = sr311_final.withColumn(
    "grid_key",
    F.concat_ws("_", F.col("lat_4"), F.col("lon_4"))
)

# %%
from pyspark.sql import functions as F

# aggregate 311 complaints within each hour + grid
sr311_agg = (
    sr311_with_grid
        .groupBy("date", "hour", "grid_key")
        .agg(
            F.count("*").alias("complaints_hour"),
            F.sum( F.when(F.col("complaint_group") == "noise", 1).otherwise(0) ).alias("noise_hour"),
            F.sum( F.when(F.col("complaint_group") == "heat_hot_water", 1).otherwise(0) ).alias("heat_hour"),
            F.sum( F.when(F.col("complaint_group") == "other", 1).otherwise(0) ).alias("other_hour")
        )
)

# %%
joined = (
    turn_with_grid
        .join(
            sr311_agg,
            on=["date", "hour", "grid_key"],
            how="left"
        )
)

# %%
joined = joined.fillna({
    "complaints_hour": 0,
    "noise_hour": 0,
    "heat_hour": 0,
    "other_hour": 0
})

# %%
joined.printSchema()
# Out:
# root
#  |-- date: date (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- grid_key: string (nullable = false)
#  |-- dt: timestamp (nullable = true)
#  |-- weekday_num: integer (nullable = true)
#  |-- is_weekend: integer (nullable = false)
#  |-- tod_bucket: string (nullable = false)
#  |-- transit_mode: string (nullable = true)
#  |-- station_complex_id: string (nullable = true)
#  |-- station_complex: string (nullable = true)
#  |-- borough: string (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- fare_class_category: string (nullable = true)
#  |-- ridership: integer (nullable = true)
#  |-- transfers: integer (nullable = true)
#  |-- total_flow: integer (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- Georeference: string (nullable = true)
#  |-- lat_4: double (nullable = true)
#  |-- lon_4: double (nullable = true)
#  |-- complaints_hour: long (nullable = false)
#  |-- noise_hour: long (nullable = false)
#  |-- heat_hour: long (nullable = false)
#  |-- other_hour: long (nullable = false)

# %% [markdown]
# ## Exporting

# %%
from pyspark.sql import functions as F

# ridership by grid / hour / time-of-day bucket
turn_panel = (
    turn_with_grid
        .groupBy(
            "date",
            "hour",
            "weekday_num",
            "is_weekend",
            "tod_bucket",
            "grid_key",
            "borough",
            "station_complex"
        )
        .agg(
            F.sum("total_flow").alias("flow_sum"),
            F.sum("ridership").alias("ridership_sum"),
            F.sum("transfers").alias("transfers_sum")
        )
)

turn_panel.show(5, truncate=False)
turn_panel.printSchema()
# Out:
# [Stage 9:===================================>                     (15 + 9) / 24]
# +----------+----+-----------+----------+----------+----------------+--------+----------------------------------+--------+-------------+-------------+
# |date      |hour|weekday_num|is_weekend|tod_bucket|grid_key        |borough |station_complex                   |flow_sum|ridership_sum|transfers_sum|
# +----------+----+-----------+----------+----------+----------------+--------+----------------------------------+--------+-------------+-------------+
# |2024-02-05|0   |2          |0         |Off-Peak  |40.8572_-73.8676|Bronx   |Pelham Pkwy (2,5)                 |19      |18           |1            |
# |2024-02-05|0   |2          |0         |Off-Peak  |40.8839_-73.8626|Bronx   |219 St (2,5)                      |6       |6            |0            |
# |2024-02-05|1   |2          |0         |Off-Peak  |40.6227_-74.0284|Brooklyn|86 St (R)                         |10      |9            |1            |
# |2024-02-05|1   |2          |0         |Off-Peak  |40.7114_-73.8896|Queens  |Middle Village-Metropolitan Av (M)|2       |2            |0            |
# |2024-02-05|1   |2          |0         |Off-Peak  |40.7128_-73.9514|Brooklyn|Lorimer St (L)/Metropolitan Av (G)|2       |2            |0            |
# +----------+----+-----------+----------+----------+----------------+--------+----------------------------------+--------+-------------+-------------+
# only showing top 5 rows
#
# root
#  |-- date: date (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- weekday_num: integer (nullable = true)
#  |-- is_weekend: integer (nullable = false)
#  |-- tod_bucket: string (nullable = false)
#  |-- grid_key: string (nullable = false)
#  |-- borough: string (nullable = true)
#  |-- station_complex: string (nullable = true)
#  |-- flow_sum: long (nullable = true)
#  |-- ridership_sum: long (nullable = true)
#  |-- transfers_sum: long (nullable = true)

# %%
# complaint counts per grid / hour / time-of-day
sr311_panel = (
    sr311_with_grid
        .groupBy(
            "date",
            "hour",
            "weekday_num",
            "is_weekend",
            "tod_bucket",
            "grid_key",
            "borough_clean"
        )
        .agg(
            F.count("*").alias("complaints_total"),
            F.sum(F.when(F.col("complaint_group") == "noise", 1).otherwise(0)).alias("complaints_noise"),
            F.sum(F.when(F.col("complaint_group") == "heat_hot_water", 1).otherwise(0)).alias("complaints_heat"),
            F.sum(F.when(F.col("complaint_group") == "other", 1).otherwise(0)).alias("complaints_other")
        )
)

sr311_panel.show(5, truncate=False)
sr311_panel.printSchema()
# Out:
# [Stage 12:=====>                                                  (1 + 10) / 11]
# +----------+----+-----------+----------+----------+----------------+-------------+----------------+----------------+---------------+----------------+
# |date      |hour|weekday_num|is_weekend|tod_bucket|grid_key        |borough_clean|complaints_total|complaints_noise|complaints_heat|complaints_other|
# +----------+----+-----------+----------+----------+----------------+-------------+----------------+----------------+---------------+----------------+
# |2024-02-12|23  |2          |0         |Off-Peak  |40.844_-73.8195 |bronx        |1               |0               |0              |1               |
# |2024-02-12|23  |2          |0         |Off-Peak  |40.8944_-73.8577|bronx        |1               |0               |1              |0               |
# |2024-02-12|20  |2          |0         |Off-Peak  |40.6155_-73.9938|brooklyn     |1               |0               |0              |1               |
# |2024-02-12|20  |2          |0         |Off-Peak  |40.7282_-73.982 |manhattan    |1               |1               |0              |0               |
# |2024-02-12|20  |2          |0         |Off-Peak  |40.7739_-73.9822|manhattan    |1               |0               |0              |1               |
# +----------+----+-----------+----------+----------+----------------+-------------+----------------+----------------+---------------+----------------+
# only showing top 5 rows
#
# root
#  |-- date: date (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- weekday_num: integer (nullable = true)
#  |-- is_weekend: integer (nullable = false)
#  |-- tod_bucket: string (nullable = false)
#  |-- grid_key: string (nullable = false)
#  |-- borough_clean: string (nullable = true)
#  |-- complaints_total: long (nullable = false)
#  |-- complaints_noise: long (nullable = true)
#  |-- complaints_heat: long (nullable = true)
#  |-- complaints_other: long (nullable = true)

# %%
# join on time + grid
hourly_panel = (
    turn_panel.alias("t")
        .join(
            sr311_panel.alias("c"),
            on=[
                "date",
                "hour",
                "weekday_num",
                "is_weekend",
                "tod_bucket",
                "grid_key"
            ],
            how="left"
        )
        # keep station + borough names from turnstile, 311 borough as backup
        .withColumn(
            "borough_final",
            F.coalesce(F.col("t.borough"), F.col("c.borough_clean"))
        )
        .fillna(
            {
                "complaints_total": 0,
                "complaints_noise": 0,
                "complaints_heat": 0,
                "complaints_other": 0,
            }
        )
)

hourly_panel.show(10, truncate=False)
hourly_panel.printSchema()
# Out:
# +----------+----+-----------+----------+----------+----------------+---------+----------------------------------+--------+-------------+-------------+-------------+----------------+----------------+---------------+----------------+-------------+
# |date      |hour|weekday_num|is_weekend|tod_bucket|grid_key        |borough  |station_complex                   |flow_sum|ridership_sum|transfers_sum|borough_clean|complaints_total|complaints_noise|complaints_heat|complaints_other|borough_final|
# +----------+----+-----------+----------+----------+----------------+---------+----------------------------------+--------+-------------+-------------+-------------+----------------+----------------+---------------+----------------+-------------+
# |2024-02-05|0   |2          |0         |Off-Peak  |40.8572_-73.8676|Bronx    |Pelham Pkwy (2,5)                 |19      |18           |1            |NULL         |0               |0               |0              |0               |Bronx        |
# |2024-02-05|0   |2          |0         |Off-Peak  |40.8839_-73.8626|Bronx    |219 St (2,5)                      |6       |6            |0            |NULL         |0               |0               |0              |0               |Bronx        |
# |2024-02-05|1   |2          |0         |Off-Peak  |40.6227_-74.0284|Brooklyn |86 St (R)                         |10      |9            |1            |NULL         |0               |0               |0              |0               |Brooklyn     |
# |2024-02-05|1   |2          |0         |Off-Peak  |40.7114_-73.8896|Queens   |Middle Village-Metropolitan Av (M)|2       |2            |0            |NULL         |0               |0               |0              |0               |Queens       |
# |2024-02-05|1   |2          |0         |Off-Peak  |40.7128_-73.9514|Brooklyn |Lorimer St (L)/Metropolitan Av (G)|2       |2            |0            |NULL         |0               |0               |0              |0               |Brooklyn     |
# |2024-02-05|1   |2          |0         |Off-Peak  |40.7795_-73.9556|Manhattan|86 St (4,5,6)                     |47      |45           |2            |NULL         |0               |0               |0              |0               |Manhattan    |
# |2024-02-05|1   |2          |0         |Off-Peak  |40.6799_-73.9409|Brooklyn |Kingston-Throop Avs (C)           |10      |10           |0            |NULL         |0               |0               |0              |0               |Brooklyn     |
# |2024-02-05|1   |2          |0         |Off-Peak  |40.5761_-73.9759|Brooklyn |W 8 St-NY Aquarium (F,Q)          |1       |1            |0            |NULL         |0               |0               |0              |0               |Brooklyn     |
# |2024-02-05|2   |2          |0         |Off-Peak  |40.747_-73.9438 |Queens   |Court Sq (E,G,M,7)                |3       |3            |0            |NULL         |0               |0               |0              |0               |Queens       |
# |2024-02-05|2   |2          |0         |Off-Peak  |40.888_-73.8603 |Bronx    |225 St (2,5)                      |5       |5            |0            |NULL         |0               |0               |0              |0               |Bronx        |
# +----------+----+-----------+----------+----------+----------------+---------+----------------------------------+--------+-------------+-------------+-------------+----------------+----------------+---------------+----------------+-------------+
# only showing top 10 rows
#
# root
#  |-- date: date (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- weekday_num: integer (nullable = true)
#  |-- is_weekend: integer (nullable = false)
#  |-- tod_bucket: string (nullable = false)
#  |-- grid_key: string (nullable = false)
#  |-- borough: string (nullable = true)
#  |-- station_complex: string (nullable = true)
#  |-- flow_sum: long (nullable = true)
#  |-- ridership_sum: long (nullable = true)
#  |-- transfers_sum: long (nullable = true)
#  |-- borough_clean: string (nullable = true)
#  |-- complaints_total: long (nullable = false)
#  |-- complaints_noise: long (nullable = false)
#  |-- complaints_heat: long (nullable = false)
#  |-- complaints_other: long (nullable = false)
#  |-- borough_final: string (nullable = true)

# %%
# pick a folder for cleaned data
output_path = "/home/wlevine/Walrus/Processed/hourly_panel"

(
    hourly_panel
        .repartition(50)          # bump this up/down depending on cluster
        .write
        .mode("overwrite")
        .parquet(output_path)
)
# Out:
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 63.33% for 12 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 58.46% for 13 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 54.29% for 14 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 50.67% for 15 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 47.50% for 16 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 44.71% for 17 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 42.22% for 18 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 40.00% for 19 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 38.00% for 20 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 36.19% for 21 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 34.55% for 22 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 33.04% for 23 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 31.67% for 24 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 30.40% for 25 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 29.23% for 26 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 28.15% for 27 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 27.14% for 28 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 26.21% for 29 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 25.33% for 30 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 24.52% for 31 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 23.75% for 32 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 23.03% for 33 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 22.35% for 34 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 21.71% for 35 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 21.11% for 36 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 20.54% for 37 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 20.00% for 38 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 19.49% for 39 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 19.00% for 40 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 18.54% for 41 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 18.10% for 42 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 17.67% for 43 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 17.27% for 44 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 16.89% for 45 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 16.52% for 46 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 16.17% for 47 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 15.83% for 48 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 15.51% for 49 writers
# 25/11/24 11:53:10 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 15.20% for 50 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 15.51% for 49 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 15.83% for 48 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 16.17% for 47 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 16.52% for 46 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 16.89% for 45 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 17.27% for 44 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 17.67% for 43 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 18.10% for 42 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 18.54% for 41 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 19.00% for 40 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 19.49% for 39 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 20.00% for 38 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 20.54% for 37 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 21.11% for 36 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 21.71% for 35 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 22.35% for 34 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 23.03% for 33 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 23.75% for 32 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 24.52% for 31 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 25.33% for 30 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 26.21% for 29 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 27.14% for 28 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 28.15% for 27 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 29.23% for 26 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 30.40% for 25 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 31.67% for 24 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 33.04% for 23 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 34.55% for 22 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 36.19% for 21 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 38.00% for 20 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 40.00% for 19 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 42.22% for 18 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 44.71% for 17 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 47.50% for 16 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 50.67% for 15 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 54.29% for 14 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 58.46% for 13 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 63.33% for 12 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 25/11/24 11:53:11 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
        .appName("Walrus_Modeling")
        .getOrCreate()
)

panel_path = "/home/wlevine/Walrus/Processed/hourly_panel"
panel = spark.read.parquet(panel_path)

panel.show(5)
panel.printSchema()
# Out:
# 25/11/24 11:53:21 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# +----------+----+-----------+----------+----------+----------------+---------+--------------------+--------+-------------+-------------+-------------+----------------+----------------+---------------+----------------+-------------+
# |      date|hour|weekday_num|is_weekend|tod_bucket|        grid_key|  borough|     station_complex|flow_sum|ridership_sum|transfers_sum|borough_clean|complaints_total|complaints_noise|complaints_heat|complaints_other|borough_final|
# +----------+----+-----------+----------+----------+----------------+---------+--------------------+--------+-------------+-------------+-------------+----------------+----------------+---------------+----------------+-------------+
# |2024-02-10|   3|          7|         1|  Off-Peak|  40.6932_-73.99| Brooklyn|Court St (R)/Boro...|      12|           12|            0|         NULL|               0|               0|              0|               0|     Brooklyn|
# |2024-02-07|  14|          4|         0|  Off-Peak|  40.6814_-73.88| Brooklyn|    Norwood Av (J,Z)|     101|          101|            0|         NULL|               0|               0|              0|               0|     Brooklyn|
# |2024-02-09|  23|          6|         0|  Off-Peak|40.7234_-73.9899|Manhattan|            2 Av (F)|     832|          830|            2|         NULL|               0|               0|              0|               0|    Manhattan|
# |2024-02-06|   2|          3|         0|  Off-Peak|40.6551_-74.0036| Brooklyn|       36 St (D,N,R)|      16|           16|            0|         NULL|               0|               0|              0|               0|     Brooklyn|
# |2024-02-10|  15|          7|         1|  Off-Peak|40.6864_-73.9166| Brooklyn|       Halsey St (J)|     202|          198|            4|         NULL|               0|               0|              0|               0|     Brooklyn|
# +----------+----+-----------+----------+----------+----------------+---------+--------------------+--------+-------------+-------------+-------------+----------------+----------------+---------------+----------------+-------------+
# only showing top 5 rows
#
# root
#  |-- date: date (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- weekday_num: integer (nullable = true)
#  |-- is_weekend: integer (nullable = true)
#  |-- tod_bucket: string (nullable = true)
#  |-- grid_key: string (nullable = true)
#  |-- borough: string (nullable = true)
#  |-- station_complex: string (nullable = true)
#  |-- flow_sum: long (nullable = true)
#  |-- ridership_sum: long (nullable = true)
#  |-- transfers_sum: long (nullable = true)
#  |-- borough_clean: string (nullable = true)
#  |-- complaints_total: long (nullable = true)
#  |-- complaints_noise: long (nullable = true)
#  |-- complaints_heat: long (nullable = true)
#  |-- complaints_other: long (nullable = true)
#  |-- borough_final: string (nullable = true)
